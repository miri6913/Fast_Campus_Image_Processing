# %% [markdown]
# Chapter 1. 축구 중계를 위한 스포츠 업계 컴퓨터 비전 프로젝트

# %% [markdown]
# ## **Chapter 2. 제조업 공정 시스템 자동화를 위한 제조업 컴퓨터 비전 프로젝트**
#
# Config file in yolo
#
# how to install tesseract ocr in colab

# %% [markdown]
# Part 3. 이커머스, 제조, 스포츠 도메인에서 컴퓨터 비전 Final Project 실습
